# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
#
# In this lab, you'll practice your scraping skills on an online music magazine and events website called Resident Advisor.
#
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://ra.co website. For reproducibility we will use the [Internet Archive](https://archive.org/) Wayback Machine to retrieve a version of this page from March 2019.
#
# Start by navigating to the events page [here](https://web.archive.org/web/20210325230938/https://ra.co/events/us/newyork?week=2019-03-30) in your browser. It should look something like this:
#
# <img src="images/ra_top.png">

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page
#
# The function should return a Pandas DataFrame with columns for the `Event_Name`, `Venue`, and `Number_of_Attendees`.
#
# Start by importing the relevant libraries, making a request to the relevant URL, and exploring the contents of the response with `BeautifulSoup`. Then fill in the `scrape_events` function with the relevant code.

# %%
# Relevant imports
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time

# insert comment for small change

# %%
EVENTS_PAGE_URL = "https://web.archive.org/web/20210326225933/https://ra.co/events/us/newyork?week=2019-03-30"

# Exploration: making the request and parsing the response
response = requests.get(EVENTS_PAGE_URL)
soup = BeautifulSoup(response.content, "html.parser")

# %%
# Find the container with event listings in it
events_div = soup.find('div',attrs={"data-tracking-id": "events-all"})
listings = events_div.find("ul").find("li")

print(listings.text)
# Out:
# ̸Sat, 30 MarUnterMania IIMary Yuzovskaya, Manni Dee, Umfang, Juana, The Lady MachineTBA - New YorkRARA Tickets457Cocoon New York: Sven Väth, Ilario Alicante, Butch & TaimurSven Vath, Butch, Taimur, Ilario Alicante99 Scott AveRARA Tickets407Horse Meat Disco - New York ResidencyHorse Meat Disco, The Carry Nation, Amber ValentineElsewhereRARA Tickets375RA PickRave: Underground Resistance All NightNomadico, Mark FlashNowadaysRARA Tickets232Detroit techno's most iconic crew dispatches two of its DJs for a rare New York gig at one of the city's homiest clubs. Believe You Me // Beta Librae, Stephan Kimbel, Born 2 BoogieBeta Librae, Stephan KimbelTBA - New YorkRARA Tickets89M.A.N.D.Y. with DJ Lisa Frank Plus Mnmlktchn with DJ QuM.A.N.D.Y., DJ Qu, Michel Harruch, DJ Lisa FrankGood RoomRARA Tickets87Nails & Wax presents: RekaReka, pulsewidthmod, dolli B, Andres TavioH0L0RARA Tickets67Wings of Illusion - Burning Man 2019 Art Car FundraiserAmine K, Bo (Borzu), CarlitaBogart HouseRARA Tickets30TBA Brooklyn 6th Anniversary34th Street John, Elon, Losoul, Connie, Pjay, Deep Woods, Eric Shans, Emma (2), OktaveTBA BrooklynRARA Tickets21Schimanski presents: Alan FitzpatrickAlan Fitzpatrick, AvisionSchimanskiRARA Tickets14[CANCELLED] Undivided: The Return of Beave101bklynRARA Tickets11Bushwick A/V (Afterhours 4am): Rendezvous ShowcasePereira, CGC, ArviPolygon BKRARA Tickets11Rollup with DJ Spider / zorenLo / For Future's SakeDJ Spider, zorenLo, For Future's SakeRose GoldRARA Tickets9D'noir AM Feat. Chriss Vargas & Anthony LopezChriss Vargas, Anthony LopezPolygon BKRARA Tickets4The Scene presents: AriesHypnotixErisRARA Tickets3Ravel Penthouse 808 Rooftop Party Everyone Free Till 1am on ListRavel HotelRARA Tickets2Vintage Culture presents So Track BoaVolkoder, Vintage CultureKings Hall - Avant GardnerRARA Tickets1Ishan, Jonboyice, Ragazzi // Sonia Release PartySunnyvaleRARA Tickets1Celebrate Your Birthday at Ravel Penthouse 808 SaturdaysPenthouse808RARA Tickets1Clubdub Springmassivenyc_001 Featuring: 6blocc6BLOCC, Mike MorganTBA - New YorkRARA Tickets32Greg Beato, Quavius, Galcher LustwerkGalcher Lustwerk, Greg Beato, QuaviusBossa Nova Civic Club14House of Love with David HohmeDavid Hohme, Amy Jor, Lolo with the Light, Arnaud MullerHouse Of Yes7Byron The Aquarius & ToribioByron The Aquarius, ToribioLe Bain7ANTES x Saturday Mass with JKrivJKriv, DGROThe Williamsburg Hotel7Shaker Mountain (The Party)Baltra, p.leone, Pascale ProjectBlack Flamingo6Earthbound ViiiDJ StiifArt Cafe/Bar5J.Worra, Chuurch, Charmae, Bad Ginger, ConceptBad Ginger, J. WorraKnitting Factory4Sole Rehab 040 - Sis Girl and Séance MichaelGhost Stories, Sis Girl, Séance MichaelTBA - Rochester4Against The GrainDave Pech, Decibel Flekx, Aldo Ron Sanchez, Past Deep, SPEEDŸ14B Rooftop / Lounge3Rekert: Seth Magoon Joe BronsonDisgonuts, PK.KID, Seth MagoonJupiter Disco3Pyramid: Kenny Glasgow at Lockhouse Distillery & BarKenny GlasgowLockhouse Distillery and Bar3Time / Place: Basic Soul Unit J-ULBasic Soul Unit, J-ULTBA - Buffalo3Event CanceledMister Joshooa, Ryan Dahl, Hatos101bklyn2Musclecars presents...Coloring Lessons 1 Year AnniversaryCarlos Sanchez, MusclecarsMood Ring2DJ Aspin b2b The Space WandererThe Space Wanderer, DJ AspinSisters2Dub Disco w/ Monolithic, Special GuestMonolithicBaby's All Right2Fatoumata DiawaraLe Poisson Rouge1Astral Turf: A Springy Spacey Dance PartyUniondocs1Dead Crew Orbit Live PA March ShowcaseTsunami Bass ExperienceThe Brown Note1Petra, Matthusen & Lang, White & Pitsiokos, and ZornH0L0̸Sun, 31 MarSunday: Soul SummitNowadaysRARA Tickets132New Dad & Aaron Clark (Honcho)Aaron Clark, New DadAce Hotel3ParadiscoOccupy The DiscoLe Bain3Sunday Soiree: Unknown Showcase (Detroit)Ryan Dahl, HatosTBA Brooklyn3Birdcage with Justin StraussJustin StraussLe Bain2Tony Touch & Mrvoodoo Ray - FunkboxnycChelsea Music Hall2Threshold_ with Olex Trebek, Fergus Waveforms, Lilei, and lambfaceFergus Waveforms, Lilei, lambface, Olex TrebekH0L02Astral Turf: A Springy Spacey Dance Party ...

# %%
# Find a list of events by date within that container
dates = listings.findChildren(recursive=False)

print("0. ",dates[0].text[:100])
print("1. ",dates[1].text[:100])
print("2. ",dates[2].text[:100])
# Out:
# 0.  ̸Sat, 30 MarUnterMania IIMary Yuzovskaya, Manni Dee, Umfang, Juana, The Lady MachineTBA - New YorkRA
# 1.
# 2.  ̸Sun, 31 MarSunday: Soul SummitNowadaysRARA Tickets132New Dad & Aaron Clark (Honcho)Aaron Clark, New

# %%
# Extract the date (e.g. Sat, 30 Mar) from one of those containers
date_1 = dates[0]
date = date_1.find("div",class_="sticky-header").text
date = date.strip("'̸")
date
# Out:
# 'Sat, 30 Mar'

# %%
# Extract the name, venue, and number of attendees from one of the
# events within that container
date_1_events = date_1.findChildren("ul")
name = date_1_events[0].find("h3").text
print(name)

rest = date_1_events[0].findAll("div",attrs={"height": 30})

venue = rest[0].text
print(venue)

num_attendees = int(rest[-1].text)
print(num_attendees)
# Out:
# UnterMania II
# TBA - New York
# 457

# %%
# Loop over all of the event entries, extract this information
# from each, and assemble a dataframe
rows = []
for date_container in dates:
    
    # check if date is valid
    if not date_container.text:
        continue
        
    # extract date
    date = date_container.find("div",class_="sticky-header").text
    date = date.strip("'̸")
    
    # loop over all events
    events = date_container.findChildren("ul")
    for event in events:
        name = event.find("h3").text
        v_plus_a = event.findAll("div", attrs={"height": 30})
        venue = v_plus_a[0].text
        try:
            attendees = int(v_plus_a[-1].text)
        except ValueError:
            attendees = np.nan
            
        rows.append([name, venue, date, attendees])

df = pd.DataFrame(rows)
df
# Out:
#                                                      0  \
# 0                                        UnterMania II
# 1    Cocoon New York: Sven Väth, Ilario Alicante, B...
# 2                Horse Meat Disco - New York Residency
# 3               Rave: Underground Resistance All Night
# 4    Believe You Me // Beta Librae, Stephan Kimbel,...
# ..                                                 ...
# 114                               A Night at the Baths
# 115                                        Blaqk Audio
# 116                                     Erik the Lover
# 117                                    Wax On Vissions
# 118            Schimanski & Good Looks present: Mercer
#
#                               1            2      3
# 0                TBA - New York  Sat, 30 Mar  457.0
# 1                  99 Scott Ave  Sat, 30 Mar  407.0
# 2                     Elsewhere  Sat, 30 Mar  375.0
# 3                      Nowadays  Sat, 30 Mar  232.0
# 4                TBA - New York  Sat, 30 Mar   89.0
# ..                          ...          ...    ...
# 114             C'mon Everybody   Fri, 5 Apr    1.0
# 115  Music Hall of Williamsburg   Fri, 5 Apr    1.0
# 116                       Erv's   Fri, 5 Apr    1.0
# 117                   Starliner   Fri, 5 Apr    1.0
# 118                  Schimanski   Fri, 5 Apr    1.0
#
# [119 rows x 4 columns]

# %%
# Bring it all together in a function that makes the request, gets the
# list of entries from the response, loops over that list to extract the
# name, venue, date, and number of attendees for each event, and returns
# that list of events as a dataframe

def scrape_events(events_page_url):
    # make request
    response = requests.get(events_page_url)
    soup = BeautifulSoup(response.content, "html.parser")
    
    # find relevant container
    events_div = soup.find('div',attrs={"data-tracking-id": "events-all"})
    listings = events_div.find("ul").find("li")
    dates = listings.findChildren(recursive=False)
    
    # loop over dates
    rows = []
    for date_container in dates:
    
        # check if date is valid
        if not date_container.text:
            continue
        
        # extract date
        date = date_container.find("div",class_="sticky-header").text
        date = date.strip("'̸")
    
        # loop over all events
        events = date_container.findChildren("ul")
        for event in events:
            name = event.find("h3").text
            v_plus_a = event.findAll("div", attrs={"height": 30})
            venue = v_plus_a[0].text
            try:
                attendees = int(v_plus_a[-1].text)
            except ValueError:
                attendees = np.nan
            
            rows.append([name, venue, date, attendees])

    df = pd.DataFrame(rows)
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return df

# %%
# Test out your function
scrape_events(EVENTS_PAGE_URL)
# Out:
#                                             Event_Name  \
# 0                                        UnterMania II
# 1    Cocoon New York: Sven Väth, Ilario Alicante, B...
# 2                Horse Meat Disco - New York Residency
# 3               Rave: Underground Resistance All Night
# 4    Believe You Me // Beta Librae, Stephan Kimbel,...
# ..                                                 ...
# 114                               A Night at the Baths
# 115                                        Blaqk Audio
# 116                                     Erik the Lover
# 117                                    Wax On Vissions
# 118            Schimanski & Good Looks present: Mercer
#
#                           Venue   Event_Date  Number_of_Attendees
# 0                TBA - New York  Sat, 30 Mar                457.0
# 1                  99 Scott Ave  Sat, 30 Mar                407.0
# 2                     Elsewhere  Sat, 30 Mar                375.0
# 3                      Nowadays  Sat, 30 Mar                232.0
# 4                TBA - New York  Sat, 30 Mar                 89.0
# ..                          ...          ...                  ...
# 114             C'mon Everybody   Fri, 5 Apr                  1.0
# 115  Music Hall of Williamsburg   Fri, 5 Apr                  1.0
# 116                       Erv's   Fri, 5 Apr                  1.0
# 117                   Starliner   Fri, 5 Apr                  1.0
# 118                  Schimanski   Fri, 5 Apr                  1.0
#
# [119 rows x 4 columns]

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page
#
# As you scroll down, there should be a button labeled "Next Week" that will take you to the next page of events. Write code to find that button and extract the URL from it.
#
# This is a relative path, so make sure you add `https://web.archive.org` to the front to get the URL.
#
# ![next page](images/ra_next.png)

# %%
# Find the button, find the relative path, create the URL for the current `soup`
svg = soup.find("svg", attrs={"aria-label": "Right arrow"})
parent = svg.parent
link = svg.parent.previousSibling

rel_path = link.get("href")
next_page_url = "https://web.archive.org" + rel_path
next_page_url
# Out:
# 'https://web.archive.org/web/20210326225933/https://ra.co/events/us/newyork?week=2019-04-06'

# %%
# Fill in this function, to take in the current page's URL and return the
# next page's URL
def next_page(url):
    #Your code here
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    
    svg = soup.find("svg", attrs={"aria-label": "Right arrow"})
    parent = svg.parent
    link = svg.parent.previousSibling
    rel_path = link.get("href")
    next_page_url = "https://web.archive.org" + rel_path
    return next_page_url

# %%
# Test out your function
next_page(EVENTS_PAGE_URL)
# Out:
# 'https://web.archive.org/web/20210326225933/https://ra.co/events/us/newyork?week=2019-04-06'

# %% [markdown]
# ## Scrape the Next 500 Events
#
# In other words, repeatedly call `scrape_events` and `next_page` until you have assembled a dataframe with at least 500 rows.
#
# Display the data sorted by the number of attendees, greatest to least.
#
# We recommend adding a brief `time.sleep` call between `requests.get` calls to avoid rate limiting.

# %%
# Your code here
final_df = pd.DataFrame()
current_url = EVENTS_PAGE_URL

while final_df.shape[0] <= 500:
    df = scrape_events(current_url)
    time.sleep(2)
    final_df = pd.concat([final_df, df])
    current_url = next_page(current_url)
    time.sleep(2)
    
final_df
# Out:
#                                             Event_Name            Venue  \
# 0                                        UnterMania II   TBA - New York
# 1    Cocoon New York: Sven Väth, Ilario Alicante, B...     99 Scott Ave
# 2                Horse Meat Disco - New York Residency        Elsewhere
# 3               Rave: Underground Resistance All Night         Nowadays
# 4    Believe You Me // Beta Librae, Stephan Kimbel,...   TBA - New York
# ..                                                 ...              ...
# 119                Sleepy & Boo, Unseen., Dysco, Joeoh        Rose Gold
# 120        Diving for Disco with Jake From Extra Water  Our Wicked Lady
# 121  The Happy Hour After Work Party at Doha Nightclub        Doha Club
# 122                                 Best of the Boogie            Erv's
# 123  [CANCELLED] Sound New York Pres Schuld, Sven M...       30 Wall St
#
#       Event_Date  Number_of_Attendees
# 0    Sat, 30 Mar                457.0
# 1    Sat, 30 Mar                407.0
# 2    Sat, 30 Mar                375.0
# 3    Sat, 30 Mar                232.0
# 4    Sat, 30 Mar                 89.0
# ..           ...                  ...
# 119   Fri, 3 May                  2.0
# 120   Fri, 3 May                  2.0
# 121   Fri, 3 May                  1.0
# 122   Fri, 3 May                  1.0
# 123   Fri, 3 May                145.0
#
# [606 rows x 4 columns]

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully developed a pipeline to scrape a website for concert event information!
